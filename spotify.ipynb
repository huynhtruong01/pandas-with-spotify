# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('./data/spotify.csv')
df.head()
# Out:
#                                Song       Artists  Weeks at no 1  \
# 0                               WAP       Cardi B            1.0
# 1  Savage Love (Laxed – Siren Beat)     Jawsh 685            2.0
# 2                          Cardigan  Taylor Swift            1.0
# 3                          Rockstar        DaBaby            7.0
# 4                        Rain on Me     Lady Gaga            1.0
#
#    Average_Streams (Millions) Date_Published   Date_Achieved
# 0                        40.3  7 August 2020  20 August 2020
# 1                        32.2   11 June 2020   6 August 2020
# 2                        35.7   24 July 2020    30 July 2020
# 3                        37.4  24 April 2020     4 June 2020
# 4                        41.6    22 May 2020     28 May 2020

# %%
df.describe(include='all')
# Out:
#             Song Artists  Weeks at no 1  Average_Streams (Millions)  \
# count         68      66      68.000000                   68.000000
# unique        67      46            NaN                         NaN
# top     Rockstar   Drake            NaN                         NaN
# freq           2       4            NaN                         NaN
# mean         NaN     NaN       6.169118                   31.441176
# std          NaN     NaN       6.990596                   14.045685
# min          NaN     NaN       1.000000                    5.200000
# 25%          NaN     NaN       1.000000                   18.575000
# 50%          NaN     NaN       4.500000                   34.900000
# 75%          NaN     NaN       8.000000                   41.925000
# max          NaN     NaN      43.700000                   53.000000
#
#        Date_Published   Date_Achieved
# count              67              67
# unique             66              67
# ...

# %%
list(df.columns)
# Out:
# ['Song',
#  'Artists',
#  'Weeks at no 1',
#  'Average_Streams (Millions)',
#  'Date_Published',
#  'Date_Achieved']

# %%
df[df['Weeks at no 1'] > 6]
# Out:
#                  Song           Artists  Weeks at no 1  \
# 3            Rockstar            DaBaby            7.0
# 6     Blinding Lights        The Weeknd           13.0
# 9        Dance Monkey       Tones and I           17.0
# 12           Señorita      Shawn Mendes           14.0
# 15            7 Rings     Ariana Grande           10.0
# 18      Thank U, Next     Ariana Grande            8.0
# 23     In My Feelings             Drake            8.0
# 24            Nonstop               NaN           43.7
# 30         God's Plan             Drake           11.0
# 32           Rockstar       Post Malone           17.0
# 36  Despacito (Remix)        Luis Fonsi           14.0
# 38       Shape of You        Ed Sheeran           14.0
# 41             Closer  The Chainsmokers           11.0
# 43          One Dance             Drake           14.0
# 44               Work           Rihanna            9.0
# 47              Sorry               NaN           28.8
# ...

# %% [markdown]
# ## Top 5 trending

# %%
top5Trending = df['Weeks at no 1'].sort_values(ascending=False).head()
top5Trending
# Out:
# 24    43.7
# 47    28.8
# 9     17.0
# 32    17.0
# 12    14.0
# Name: Weeks at no 1, dtype: float64

# %%
df_top_5_trending = df[['Song', 'Weeks at no 1', 'Average_Streams (Millions)', 'Date_Published']]
df_top_5_trending['Average_Streams (Millions)'].sort_values(ascending=False)
df_top_5_trending['Song'].head()
# Out:
# 0                                 WAP
# 1    Savage Love (Laxed – Siren Beat)
# 2                            Cardigan
# 3                            Rockstar
# 4                          Rain on Me
# Name: Song, dtype: object

# %%
df['Date_Published'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Top 5 artists

# %%
df_top_artists = df.groupby('Artists').sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17576\2444019488.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_top_artists = df.groupby('Artists').sum()

# %%
df_top_artists['Average_Streams (Millions)'].sort_values(ascending=False).head()
# Out:
# Artists
# Drake           179.8
# Post Malone     148.5
# The Weeknd      127.7
# Ed Sheeran      105.9
# Travis Scott     96.6
# Name: Average_Streams (Millions), dtype: float64

# %% [markdown]
# ## Replace NaN to current Date

# %%
df['Date_Published'].dtype
# Out:
# dtype('O')

# %%
df['Date_Published'] = df['Date_Published'].fillna(pd.Timestamp.today().strftime('%d %b %Y'))
df['Date_Achieved'] = df['Date_Achieved'].fillna(pd.Timestamp.today().strftime('%d %b %Y'))

# %%
df.iloc[1:40]
# Out:
#                                 Song           Artists  Weeks at no 1  \
# 1   Savage Love (Laxed – Siren Beat)         Jawsh 685            2.0
# 2                           Cardigan      Taylor Swift            1.0
# 3                           Rockstar            DaBaby            7.0
# 4                         Rain on Me         Lady Gaga            1.0
# 5                         The Scotts      Travis Scott            1.0
# 6                    Blinding Lights        The Weeknd           13.0
# 7                            The Box       Roddy Ricch            1.0
# 8                Lose You to Love Me      Selena Gomez            1.0
# 9                       Dance Monkey       Tones and I           17.0
# 10               Highest in the Room      Travis Scott            1.0
# 11                           Circles       Post Malone            1.0
# 12                          Señorita      Shawn Mendes           14.0
# ...

# %%
df['Weeks at no 1'].nunique()
# Out:
# 16

# %%
df.drop('Weeks at no 1')
